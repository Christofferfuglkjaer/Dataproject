# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import sklearn
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import TruncatedSVD

# %%
df = pd.read_csv('../Behandlet data.csv', sep=';', header=1, index_col=0, decimal=',')
df
# Out:
#       9,0  0,0  0,0.1  0,0.2  6,0  0,0.3  4,0  0,0.4  4,0.1  0,0.5  0,0.6  \
# 1
# 2     9.0  0.0    0.0    0.0  6.0    1.0  1.0    1.0    3.0    9.0    0.0
# 3     0.0  0.0    0.0    0.0  2.0    3.0  1.0    0.0    4.0    0.0    0.0
# 4     9.0  0.0    1.0    0.0  6.0    4.0  0.0    1.0    4.0    9.0    0.0
# 5     0.0  0.0    0.0    0.0  6.0    0.0  0.0    0.0    4.0    0.0    0.0
# 6    12.0  1.0    0.0    0.0  6.0    4.0  0.0    1.0    4.0   12.0    1.0
# ..    ...  ...    ...    ...  ...    ...  ...    ...    ...    ...    ...
# 117  12.0  0.0    3.0    1.0  6.0    4.0  0.0    1.0    4.0    9.0    0.0
# 118   9.0  0.0    1.0    0.0  6.0    0.0  3.0    0.0    4.0    9.0    0.0
# 119   9.0  0.0    4.0    0.0  0.0    4.0  0.0    0.0    4.0   12.0    0.0
# 120  12.0  0.0    0.0    0.0  6.0    3.0  0.0    0.0    4.0    9.0    0.0
# 122   9.0  1.0    0.0    0.0  6.0    3.0  0.0    0.0    4.0   12.0    3.0
#
#      0,0.7  0,0.8  6,0.1  0,0.9  4,0.2  0,0.10  3,0   0
# 1
# 2      2.0    4.0    6.0    0.0    0.0     1.0  3.0   8
# 3      0.0    0.0    6.0    1.0    3.0     0.0  0.0   9
# 4      2.0    0.0    6.0    4.0    0.0     1.0  4.0   9
# 5      0.0    0.0    2.0    0.0    4.0     0.0  3.0  13
# 6      0.0    3.0    8.0    4.0    0.0     1.0  4.0  29
# ..     ...    ...    ...    ...    ...     ...  ...  ..
# 117    0.0    0.0    6.0    3.0    0.0     1.0  0.0   3
# 118    0.0    0.0    6.0    0.0    3.0     0.0  3.0   3
# 119    3.0    4.0    6.0    4.0    0.0     0.0  3.0   4
# 120    0.0    0.0    6.0    4.0    0.0     0.0  4.0  12
# 122    2.0    3.0    6.0    3.0    0.0     1.0  4.0   6
#
# [116 rows x 19 columns]

# %%
# Removing target column
df = df.drop(['Total Row Score C'], axis=1)
X = df.values

# %%
# Singular value decomposition
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# I want 95% of the variance to be explained
svd = TruncatedSVD(n_components=14)
X = svd.fit_transform(X)

# %%
# 95% of the variance to be explained
explained_variance = np.sum(svd.explained_variance_ratio_)
print(explained_variance)
# Out:
# 0.9515589270275127
