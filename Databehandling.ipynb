# %% [markdown]
# Cleaning the Data

# %%
import pandas as pd

# Read data
df = pd.read_csv('Data for python.csv', sep=';', header=0, decimal=',')

# Remove unnecessary columns
df = df.drop(['Center','Kassenr', 'ScandcleftID', 'Unnamed: 3', 'Født', 'Materialedato A',
       'Total Row Score A', 'Goslon Score A', 'Materialedato B',
       'Total Row Score B','Goslon Score B', 'Materialedato C',
       'Anteroposterior 1.2', 'Anteroposterior 2.1', 'Vertical 1.2', 
       'Vertical 2.2', 'Transverse.2','Crowding .2', 'Spacing.2', 
       'Tooth shape/size\n.1', 'Pan 1.2','Pan 2\n.2', 
       'Goslon Score C', 'Pan 1', 'Pan 1.1'], axis=1)

# Remove rows with missing values
df = df.dropna()

# Save
df.to_csv('Data for python_cleaned.csv', sep=';', decimal=',')
df
# Out:
#      Anteroposterior 1  Anteroposterior 2  Vertical 1  Vertical 2  Transverse  \
# 1                  9.0                0.0         0.0         0.0         6.0
# 2                  9.0                0.0         0.0         0.0         6.0
# 3                  0.0                0.0         0.0         0.0         2.0
# 4                  9.0                0.0         1.0         0.0         6.0
# 5                  0.0                0.0         0.0         0.0         6.0
# ..                 ...                ...         ...         ...         ...
# 117               12.0                0.0         3.0         1.0         6.0
# 118                9.0                0.0         1.0         0.0         6.0
# 119                9.0                0.0         4.0         0.0         0.0
# 120               12.0                0.0         0.0         0.0         6.0
# 122                9.0                1.0         0.0         0.0         6.0
#
#      Crowding   Spacing  Tooth shape/size  \n  Pan 2\n  Anteroposterior 1.1  \
# 1          0.0      4.0                   0.0      4.0                  0.0
# 2          1.0      1.0                   1.0      3.0                  9.0
# 3          3.0      1.0                   0.0      4.0                  0.0
# 4          4.0      0.0                   1.0      4.0                  9.0
# 5          0.0      0.0                   0.0      4.0                  0.0
# ..         ...      ...                   ...      ...                  ...
# 117        4.0      0.0                   1.0      4.0                  9.0
# 118        0.0      3.0                   0.0      4.0                  9.0
# 119        4.0      0.0                   0.0      4.0                 12.0
# 120        3.0      0.0                   0.0      4.0                  9.0
# 122        3.0      0.0                   0.0      4.0                 12.0
#
#      Anteroposterior  Vertical 1.1  Vertical 2.1  Transverse.1  Crowding .1  \
# 1                0.0           0.0           0.0           6.0          0.0
# 2                0.0           2.0           4.0           6.0          0.0
# 3                0.0           0.0           0.0           6.0          1.0
# 4                0.0           2.0           0.0           6.0          4.0
# 5                0.0           0.0           0.0           2.0          0.0
# ..               ...           ...           ...           ...          ...
# 117              0.0           0.0           0.0           6.0          3.0
# 118              0.0           0.0           0.0           6.0          0.0
# 119              0.0           3.0           4.0           6.0          4.0
# 120              0.0           0.0           0.0           6.0          4.0
# 122              3.0           2.0           3.0           6.0          3.0
#
#      Spacing.1  Tooth shape/size\n  Pan 2\n.1  Total Row Score C
# 1          4.0                 0.0        3.0                  0
# 2          0.0                 1.0        3.0                  8
# 3          3.0                 0.0        0.0                  9
# 4          0.0                 1.0        4.0                  9
# 5          4.0                 0.0        3.0                 13
# ..         ...                 ...        ...                ...
# 117        0.0                 1.0        0.0                  3
# 118        3.0                 0.0        3.0                  3
# 119        0.0                 0.0        3.0                  4
# 120        0.0                 0.0        4.0                 12
# 122        0.0                 1.0        4.0                  6
#
# [117 rows x 19 columns]
